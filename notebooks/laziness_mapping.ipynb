# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
import scipy.stats
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter

# %%
# create a laziness mapping between Q+T and Pairwise
# that attempts to normalize the laziness between the two

qt_laziness = np.linspace(0,1,100)
pairwise_laziness = qt_laziness**(0.2)

plt.figure()
plt.plot(qt_laziness, pairwise_laziness)
plt.xlabel("Q+T Laziness")
plt.ylabel("Pairwise Laziness")
# Out:
# Text(0, 0.5, 'Pairwise Laziness')
